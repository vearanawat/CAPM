# %%
import pandas as pd

# %%
df = pd.read_csv('^NSEBANK.csv')

# %%
df
# Out:
#           Date          Open          High           Low         Close  \
# 0   2019-03-01  26941.000000  30499.150391  26928.900391  30426.800781
# 1   2019-04-01  30537.599609  30669.800781  29435.050781  29764.800781
# 2   2019-05-01  29699.800781  31783.599609  28525.449219  31375.400391
# 3   2019-06-01  31406.050781  31752.699219  30220.699219  31105.199219
# 4   2019-07-01  31271.000000  31660.750000  28537.000000  28876.000000
# 5   2019-08-01  28660.500000  28819.699219  26560.599609  27427.849609
# 6   2019-09-01  27239.199219  30801.300781  26641.349609  29103.150391
# 7   2019-10-01  29226.150391  30415.650391  27568.349609  30066.250000
# 8   2019-11-01  30196.150391  32157.050781  30013.650391  31946.099609
# 9   2019-12-01  32008.300781  32613.099609  30996.400391  32161.650391
# 10  2020-01-01  32133.150391  32465.449219  30521.300781  30833.599609
# 11  2020-02-01  29811.750000  31649.449219  29051.500000  29147.150391
# ...

# %%
df['Daily returns'] = df['Close']/df['Open'] - 1

# %%
df
# Out:
#           Date          Open          High           Low         Close  \
# 0   2019-03-01  26941.000000  30499.150391  26928.900391  30426.800781
# 1   2019-04-01  30537.599609  30669.800781  29435.050781  29764.800781
# 2   2019-05-01  29699.800781  31783.599609  28525.449219  31375.400391
# 3   2019-06-01  31406.050781  31752.699219  30220.699219  31105.199219
# 4   2019-07-01  31271.000000  31660.750000  28537.000000  28876.000000
# 5   2019-08-01  28660.500000  28819.699219  26560.599609  27427.849609
# 6   2019-09-01  27239.199219  30801.300781  26641.349609  29103.150391
# 7   2019-10-01  29226.150391  30415.650391  27568.349609  30066.250000
# 8   2019-11-01  30196.150391  32157.050781  30013.650391  31946.099609
# 9   2019-12-01  32008.300781  32613.099609  30996.400391  32161.650391
# 10  2020-01-01  32133.150391  32465.449219  30521.300781  30833.599609
# 11  2020-02-01  29811.750000  31649.449219  29051.500000  29147.150391
# ...

# %%
import numpy as np

# %%
cov = np.cov(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 cov = np.cov(df)
#
# File <__array_function__ internals>:200, in cov(*args, **kwargs)
#
# File C:\users\veara\appdata\local\programs\python\python38\lib\site-packages\numpy\lib\function_base.py:2681, in cov(m, y, rowvar, bias, ddof, fweights, aweights, dtype)
#    2678     else:
#    2679         w *= aweights
# -> 2681 avg, w_sum = average(X, axis=1, weights=w, returned=True)
#    2682 w_sum = w_sum[0]
#    2684 # Determine the normalization
#
# File <__array_function__ internals>:200, in average(*args, **kwargs)
#
# File C:\users\veara\appdata\local\programs\python\python38\lib\site-packages\numpy\lib\function_base.py:518, in average(a, axis, weights, returned, keepdims)
#     515     keepdims_kw = {'keepdims': keepdims}
#     517 if weights is None:
# --> 518     avg = a.mean(axis, **keepdims_kw)
# ...

# %%
df1 = pd.read_csv('^NSEBANK1.csv')

# %%
df1
# Out:
#            Date          Open          High           Low         Close  \
# 0    2023-02-20  41221.550781  41292.601563  40580.101563  40701.699219
# 1    2023-02-21  40784.898438  40946.199219  40508.250000  40673.601563
# 2    2023-02-22  40494.148438  40529.250000  39899.000000  39995.898438
# 3    2023-02-23  39983.699219  40147.800781  39600.250000  40001.550781
# 4    2023-02-24  40259.101563  40348.101563  39818.898438  39909.398438
# ..          ...           ...           ...           ...           ...
# 240  2024-02-13  45056.800781  45750.398438  44819.550781  45502.398438
# 241  2024-02-14  45014.648438  46170.449219  44860.750000  45908.300781
# 242  2024-02-15  46027.101563  46297.699219  45590.199219  46218.898438
# 243  2024-02-16  46454.300781  46693.398438  46264.398438  46384.851563
# 244  2024-02-19  46454.300781  46717.398438  46317.699219  46662.101563
#
#         Adj Close    Volume
# 0    40701.699219  143700.0
# 1    40673.601563  170200.0
# ...

# %%
df1['Daily returns'] = df1['Close']/df1['Open'] - 1

# %%
df1
# Out:
#            Date          Open          High           Low         Close  \
# 0    2023-02-20  41221.550781  41292.601563  40580.101563  40701.699219
# 1    2023-02-21  40784.898438  40946.199219  40508.250000  40673.601563
# 2    2023-02-22  40494.148438  40529.250000  39899.000000  39995.898438
# 3    2023-02-23  39983.699219  40147.800781  39600.250000  40001.550781
# 4    2023-02-24  40259.101563  40348.101563  39818.898438  39909.398438
# ..          ...           ...           ...           ...           ...
# 240  2024-02-13  45056.800781  45750.398438  44819.550781  45502.398438
# 241  2024-02-14  45014.648438  46170.449219  44860.750000  45908.300781
# 242  2024-02-15  46027.101563  46297.699219  45590.199219  46218.898438
# 243  2024-02-16  46454.300781  46693.398438  46264.398438  46384.851563
# 244  2024-02-19  46454.300781  46717.398438  46317.699219  46662.101563
#
#         Adj Close    Volume  Daily returns
# 0    40701.699219  143700.0      -0.012611
# ...

# %%
A = df['Daily returns'].cov(df1['Daily returns'])

# %%
A
# Out:
# 3.539992208922979e-05

# %%
variance = df1['Daily returns'].var()

# %%
variance
# Out:
# 4.885647734937866e-05

# %%
beta = A/variance

# %%
beta
# Out:
# 0.7245696785726201

# %%
df
# Out:
#           Date          Open          High           Low         Close  \
# 0   2019-03-01  26941.000000  30499.150391  26928.900391  30426.800781
# 1   2019-04-01  30537.599609  30669.800781  29435.050781  29764.800781
# 2   2019-05-01  29699.800781  31783.599609  28525.449219  31375.400391
# 3   2019-06-01  31406.050781  31752.699219  30220.699219  31105.199219
# 4   2019-07-01  31271.000000  31660.750000  28537.000000  28876.000000
# 5   2019-08-01  28660.500000  28819.699219  26560.599609  27427.849609
# 6   2019-09-01  27239.199219  30801.300781  26641.349609  29103.150391
# 7   2019-10-01  29226.150391  30415.650391  27568.349609  30066.250000
# 8   2019-11-01  30196.150391  32157.050781  30013.650391  31946.099609
# 9   2019-12-01  32008.300781  32613.099609  30996.400391  32161.650391
# 10  2020-01-01  32133.150391  32465.449219  30521.300781  30833.599609
# 11  2020-02-01  29811.750000  31649.449219  29051.500000  29147.150391
# ...

# %%
x = df.loc[df['Date']=='2024-02-01']

# %%
y = df.loc[df['Date']=='2023-02-01']

# %%
x
# Out:
#           Date          Open          High           Low         Close  \
# 59  2024-02-01  46164.898438  46892.351563  44633.851563  46384.851563
#
#        Adj Close   Volume  Daily returns
# 59  46384.851563  3330600       0.004765

# %%
ret = 0.15187348

# %%
rf = 0.0711

# %%
ROE = rf + beta*(ret-rf)

# %%
ROE
# Out:
# 0.12962601444079197
